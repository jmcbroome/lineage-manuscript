# %%
import pandas as pd
import numpy as np
from scipy.stats import percentileofscore as pos
import bte

# %% [markdown]
# First, we load the tree and the label data into memory.

# %%
t = bte.MATree("seabra_zika.autolin.pb")
t
# Out:
# Finished 'from_pb' in 0.0281 seconds
# MATree object with 767 leaves.

# %%
df = pd.read_csv("seabra_zika.labels.txt",sep='\t',names=['lineage','strain'])[['strain','lineage']]
df
# Out:
#                              strain             lineage
# 0           KY288905_Uganda_1962-11                   L
# 1         OK054351_India_2021-07-28                   L
# 2         KX377336_Malaysia_1966-07                   L
# 3           MN025403_Guinea_2018-08                   L
# 4       KX601166_Senegal_1984-11-17                   L
# ...                             ...                 ...
# 3550  OK054466_Nicaragua_2016-07-13          auto.L.1.1
# 3551  OK054466_Nicaragua_2016-07-13        auto.L.1.1.1
# 3552  OK054466_Nicaragua_2016-07-13      auto.L.1.1.1.1
# 3553  OK054466_Nicaragua_2016-07-13    auto.L.1.1.1.1.2
# 3554  OK054466_Nicaragua_2016-07-13  auto.L.1.1.1.1.2.1
#
# [3555 rows x 2 columns]

# %% [markdown]
# For visualization convenience downstream, we reshape the label table by splitting the lineages into their various levels; the resulting CSV can be included in the creation of a protocol buffer or dragged-and-dropped onto Auspice to allow the user to color by any one of the levels of annotation.

# %%
counts = []
for l in df.lineage:
    elements = l.split(".")
    if elements[0] == 'auto':
        elements = elements[1:]
    counts.append(len(elements))
df['counts'] = counts
df.counts
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3550    3
# 3551    4
# 3552    5
# 3553    6
# 3554    7
# Name: counts, Length: 3555, dtype: int64

# %% [markdown]
# Only retain the highest level (max counts) entry for each strain.

# %%
df = df.dropna().sort_values("counts",ascending=False).drop_duplicates("strain")

# %%
linslots = [[] for i in range(0,df.counts.max())]
for l in df.lineage:
    elements = l.split(".")
    if elements[0] == 'auto':
        elements = elements[1:]
    for i in range(0,df.counts.max()):
        current = ".".join(elements[:i+1])
        if current == "L":
            current = "not assigned"
        linslots[i].append(current)
for i in range(1,len(linslots)):
    index = "GRI Lineage Level " + str(i)
    df[index] = linslots[i]
df
# Out:
#                               strain              lineage  counts  \
# 3554   OK054466_Nicaragua_2016-07-13   auto.L.1.1.1.1.2.1       7
# 2420            MK028861_Panama_2015   auto.L.1.1.5.1.2.1       7
# 2835   OK054450_Nicaragua_2016-08-24   auto.L.1.1.1.4.1.1       7
# 2828   OK054436_Nicaragua_2016-07-14   auto.L.1.1.1.4.1.1       7
# 1910   OK054392_Nicaragua_2016-07-27  auto.L.1.1.1.16.1.1       7
# ...                              ...                  ...     ...
# 22    KY328290_Bangladesh_2016-11-03                    L       1
# 23      MT377498_Thailand_2016-04-26                    L       1
# 17     KU179098_Indonesia_2014-12-30                    L       1
# 4        KX601166_Senegal_1984-11-17                    L       1
# 0            KY288905_Uganda_1962-11                    L       1
#
#      GRI Lineage Level 1 GRI Lineage Level 2 GRI Lineage Level 3  \
# 3554                 L.1               L.1.1             L.1.1.1
# 2420                 L.1               L.1.1             L.1.1.5
# 2835                 L.1               L.1.1             L.1.1.1
# 2828                 L.1               L.1.1             L.1.1.1
# 1910                 L.1               L.1.1             L.1.1.1
# ...                  ...                 ...                 ...
# 22          not assigned        not assigned        not assigned
# 23          not assigned        not assigned        not assigned
# 17          not assigned        not assigned        not assigned
# 4           not assigned        not assigned        not assigned
# 0           not assigned        not assigned        not assigned
#
#      GRI Lineage Level 4 GRI Lineage Level 5 GRI Lineage Level 6 SeabraLineage
# 3554           L.1.1.1.1         L.1.1.1.1.2       L.1.1.1.1.2.1        ZB.2.1
# 2420           L.1.1.5.1         L.1.1.5.1.2       L.1.1.5.1.2.1        ZB.2.0
# 2835           L.1.1.1.4         L.1.1.1.4.1       L.1.1.1.4.1.1        ZB.2.1
# 2828           L.1.1.1.4         L.1.1.1.4.1       L.1.1.1.4.1.1        ZB.2.1
# 1910          L.1.1.1.16        L.1.1.1.16.1      L.1.1.1.16.1.1        ZB.2.1
# ...                  ...                 ...                 ...           ...
# 22          not assigned        not assigned        not assigned        ZB.1.1
# 23          not assigned        not assigned        not assigned        ZB.1.1
# 17          not assigned        not assigned        not assigned        ZB.1.1
# 4           not assigned        not assigned        not assigned            ZA
# 0           not assigned        not assigned        not assigned            ZA
#
# [759 rows x 10 columns]

# %%
df.to_csv("seabra_zika.labels.split.tsv",sep='\t',index=False)

# %% [markdown]
# We retrieve Seabra's nomenclature from their [supplementary data](https://academic.oup.com/ve/article/8/1/veac029/6555351#351081937).

# %%
sdf = pd.read_excel("Supplementary_Table_S3_NEW.xlsx").set_index("id_country_date")
sdf
# Out:
#                                       order        id  seq_length      host  \
# id_country_date
# OK571913_Haiti_2014-11-25                 5  OK571913       10807     Human
# MW123921_Brazil_2016-04-26                6  MW123921       10639     Human
# MW123922_Brazil_2016-05-10                7  MW123922       10639     Human
# MW123923_Brazil_2016-06-16                8  MW123923       10651     Human
# MW123924_Brazil_2016-05-07                9  MW123924       10648     Human
# ...                                     ...       ...         ...       ...
# KF268950_CentralAfricanRepublic_1976   2029  KF268950       10755  Mosquito
# AY632535_Uganda_1947                   2175  AY632535       10794    Monkey
# KY241700_Singapore_2016-08-27          1570  KY241700       10738     Human
# KY241712_Singapore_2016-08-30          1582  KY241712       10770     Human
# EU545988_Micronesia_2007-06            2177  EU545988       10272     Human
#
#                                          host_species       ATCG%        CG%  \
# id_country_date
# OK571913_Haiti_2014-11-25                Homo sapiens  100.000000  51.095530
# MW123921_Brazil_2016-04-26               Homo sapiens  100.000000  51.124744
# MW123922_Brazil_2016-05-10               Homo sapiens   97.546012  51.093142
# MW123923_Brazil_2016-06-16               Homo sapiens   99.045671  50.968440
# MW123924_Brazil_2016-05-07               Homo sapiens   96.737754  51.016710
# ...                                               ...         ...        ...
# KF268950_CentralAfricanRepublic_1976  Aedes africanus   99.951310  50.448168
# AY632535_Uganda_1947                  sentinel monkey   99.883143  50.784830
# KY241700_Singapore_2016-08-27            Homo sapiens   99.522836  51.144814
# KY241712_Singapore_2016-08-30            Homo sapiens  100.000000  51.173435
# EU545988_Micronesia_2007-06              Homo sapiens   99.980524  51.047044
#
#                                               CountryCleaned  \
# id_country_date
# OK571913_Haiti_2014-11-25                              Haiti
# MW123921_Brazil_2016-04-26                            Brazil
# MW123922_Brazil_2016-05-10                            Brazil
# MW123923_Brazil_2016-06-16                            Brazil
# MW123924_Brazil_2016-05-07                            Brazil
# ...                                                      ...
# KF268950_CentralAfricanRepublic_1976  CentralAfricanRepublic
# AY632535_Uganda_1947                                  Uganda
# KY241700_Singapore_2016-08-27                      Singapore
# KY241712_Singapore_2016-08-30                      Singapore
# EU545988_Micronesia_2007-06                       Micronesia
#
#                                      SamplingDate_formatted  Year  ...  \
# id_country_date                                                    ...
# OK571913_Haiti_2014-11-25                        2014-11-25  2014  ...
# MW123921_Brazil_2016-04-26                       2016-04-26  2016  ...
# MW123922_Brazil_2016-05-10                       2016-05-10  2016  ...
# MW123923_Brazil_2016-06-16                       2016-06-16  2016  ...
# MW123924_Brazil_2016-05-07                       2016-05-07  2016  ...
# ...                                                     ...   ...  ...
# KF268950_CentralAfricanRepublic_1976                   1976  1976  ...
# AY632535_Uganda_1947                                   1947  1947  ...
# KY241700_Singapore_2016-08-27                    2016-08-27  2016  ...
# KY241712_Singapore_2016-08-30                    2016-08-30  2016  ...
# EU545988_Micronesia_2007-06                         2007-06  2007  ...
#
#                                      Hb_759_level2 Hb_752_level1  \
# id_country_date
# OK571913_Haiti_2014-11-25                      1.0           1.0
# MW123921_Brazil_2016-04-26                     2.0           1.0
# MW123922_Brazil_2016-05-10                     2.0           1.0
# MW123923_Brazil_2016-06-16                     2.0           1.0
# MW123924_Brazil_2016-05-07                     2.0           1.0
# ...                                            ...           ...
# KF268950_CentralAfricanRepublic_1976          11.0           NaN
# AY632535_Uganda_1947                          10.0           NaN
# KY241700_Singapore_2016-08-27                  NaN           NaN
# KY241712_Singapore_2016-08-30                  NaN           NaN
# EU545988_Micronesia_2007-06                    NaN           NaN
#
#                                      Hb_752_level2 groups_hb759 groups_hb752  \
# id_country_date
# OK571913_Haiti_2014-11-25                      1.0       ZB.2.0       ZB.2.0
# MW123921_Brazil_2016-04-26                     1.0       ZB.2.0       ZB.2.0
# MW123922_Brazil_2016-05-10                     1.0       ZB.2.0       ZB.2.0
# MW123923_Brazil_2016-06-16                     1.0       ZB.2.0       ZB.2.0
# MW123924_Brazil_2016-05-07                     1.0       ZB.2.0       ZB.2.0
# ...                                            ...          ...          ...
# KF268950_CentralAfricanRepublic_1976           NaN           ZA          NaN
# AY632535_Uganda_1947                           NaN           ZA          NaN
# KY241700_Singapore_2016-08-27                  NaN          NaN          NaN
# KY241712_Singapore_2016-08-30                  NaN          NaN          NaN
# EU545988_Micronesia_2007-06                    NaN          NaN          NaN
#
#                                      NAMING_PROPOSAL  \
# id_country_date
# OK571913_Haiti_2014-11-25                     ZB.2.0
# MW123921_Brazil_2016-04-26                    ZB.2.0
# MW123922_Brazil_2016-05-10                    ZB.2.0
# MW123923_Brazil_2016-06-16                    ZB.2.0
# MW123924_Brazil_2016-05-07                    ZB.2.0
# ...                                              ...
# KF268950_CentralAfricanRepublic_1976              ZA
# AY632535_Uganda_1947                              ZA
# KY241700_Singapore_2016-08-27                    NaN
# KY241712_Singapore_2016-08-30                    NaN
# EU545988_Micronesia_2007-06                      NaN
#
#                                                                   ids_iTOL  \
# id_country_date
# OK571913_Haiti_2014-11-25                        OK571913_Haiti_2014-11-25
# MW123921_Brazil_2016-04-26                      MW123921_Brazil_2016-04-26
# MW123922_Brazil_2016-05-10                      MW123922_Brazil_2016-05-10
# MW123923_Brazil_2016-06-16                      MW123923_Brazil_2016-06-16
# MW123924_Brazil_2016-05-07                      MW123924_Brazil_2016-05-07
# ...                                                                    ...
# KF268950_CentralAfricanRepublic_1976  KF268950_CentralAfricanRepublic_1976
# AY632535_Uganda_1947                                  AY632535_Uganda_1947
# KY241700_Singapore_2016-08-27                KY241700_Singapore_2016-08-27
# KY241712_Singapore_2016-08-30                KY241712_Singapore_2016-08-30
# EU545988_Micronesia_2007-06                    EU545988_Micronesia_2007-06
#
#                                      colour_regions_itol  colour_host_itol  \
# id_country_date
# OK571913_Haiti_2014-11-25                        #33a02c           #d9d9d9
# MW123921_Brazil_2016-04-26                       #1f78b4           #d9d9d9
# MW123922_Brazil_2016-05-10                       #1f78b4           #d9d9d9
# MW123923_Brazil_2016-06-16                       #1f78b4           #d9d9d9
# MW123924_Brazil_2016-05-07                       #1f78b4           #d9d9d9
# ...                                                  ...               ...
# KF268950_CentralAfricanRepublic_1976             #fdbf6f           #252525
# AY632535_Uganda_1947                             #c1420c           #806a61
# KY241700_Singapore_2016-08-27                    #6a3d9a           #d9d9d9
# KY241712_Singapore_2016-08-30                    #6a3d9a           #d9d9d9
# EU545988_Micronesia_2007-06                      #ffff99           #d9d9d9
#
#                                       colour_naming_itol
# id_country_date
# OK571913_Haiti_2014-11-25                        #1f78b4
# MW123921_Brazil_2016-04-26                       #1f78b4
# MW123922_Brazil_2016-05-10                       #1f78b4
# MW123923_Brazil_2016-06-16                       #1f78b4
# MW123924_Brazil_2016-05-07                       #1f78b4
# ...                                                  ...
# KF268950_CentralAfricanRepublic_1976             #c1420c
# AY632535_Uganda_1947                             #c1420c
# KY241700_Singapore_2016-08-27                        NaN
# KY241712_Singapore_2016-08-30                        NaN
# EU545988_Micronesia_2007-06                          NaN
#
# [762 rows x 29 columns]

# %% [markdown]
# Their strains are in the "NAMING_PROPOSAL" column. We transfer these names into the label table.

# %%
def get_np(strain):
    try:
        return sdf.loc[strain].NAMING_PROPOSAL
    except KeyError:
        return np.nan
df['SeabraLineage'] = df.strain.apply(get_np)
df.dropna(inplace=True)
df
# Out:
#                              strain             lineage  counts  \
# 0           KY288905_Uganda_1962-11                   L       1
# 1         OK054351_India_2021-07-28                   L       1
# 2         KX377336_Malaysia_1966-07                   L       1
# 3           MN025403_Guinea_2018-08                   L       1
# 4       KX601166_Senegal_1984-11-17                   L       1
# ...                             ...                 ...     ...
# 3550  OK054466_Nicaragua_2016-07-13          auto.L.1.1       3
# 3551  OK054466_Nicaragua_2016-07-13        auto.L.1.1.1       4
# 3552  OK054466_Nicaragua_2016-07-13      auto.L.1.1.1.1       5
# 3553  OK054466_Nicaragua_2016-07-13    auto.L.1.1.1.1.2       6
# 3554  OK054466_Nicaragua_2016-07-13  auto.L.1.1.1.1.2.1       7
#
#      GRI Lineage Level 1 GRI Lineage Level 2 GRI Lineage Level 3  \
# 0           not assigned        not assigned        not assigned
# 1           not assigned        not assigned        not assigned
# 2           not assigned        not assigned        not assigned
# 3           not assigned        not assigned        not assigned
# 4           not assigned        not assigned        not assigned
# ...                  ...                 ...                 ...
# 3550                 L.1               L.1.1               L.1.1
# 3551                 L.1               L.1.1             L.1.1.1
# 3552                 L.1               L.1.1             L.1.1.1
# 3553                 L.1               L.1.1             L.1.1.1
# 3554                 L.1               L.1.1             L.1.1.1
#
#      GRI Lineage Level 4 GRI Lineage Level 5 GRI Lineage Level 6 SeabraLineage
# 0           not assigned        not assigned        not assigned            ZA
# 1           not assigned        not assigned        not assigned        ZB.1.0
# 2           not assigned        not assigned        not assigned        ZB.1.0
# 3           not assigned        not assigned        not assigned            ZA
# 4           not assigned        not assigned        not assigned            ZA
# ...                  ...                 ...                 ...           ...
# 3550               L.1.1               L.1.1               L.1.1        ZB.2.1
# 3551             L.1.1.1             L.1.1.1             L.1.1.1        ZB.2.1
# 3552           L.1.1.1.1           L.1.1.1.1           L.1.1.1.1        ZB.2.1
# 3553           L.1.1.1.1         L.1.1.1.1.2         L.1.1.1.1.2        ZB.2.1
# 3554           L.1.1.1.1         L.1.1.1.1.2       L.1.1.1.1.2.1        ZB.2.1
#
# [3555 rows x 10 columns]

# %% [markdown]
# We can now compute the ARI between different levels of annotation and the Seabra nomenclature. Level 3 is generally the most concordant, representing lineages of about the same size.

# %%
for i in range(1, 7):
    ln = "GRI Lineage Level " + str(i)
    print(ln, ari(df.SeabraLineage, df[ln]))
# Out:
# GRI Lineage Level 1 0.06295406079320065
# GRI Lineage Level 2 0.22168505431544977
# GRI Lineage Level 3 0.467394449314314
# GRI Lineage Level 4 0.08716677740542479
# GRI Lineage Level 5 0.06346404086422941
# GRI Lineage Level 6 0.061138993113729063

# %% [markdown]
# We now test whether this value is significantly higher than expected through a simple permutation test. This is the same style of permutation test used for CHIKV and VEEV in this manuscript.

# %%
t = t.subtree(df.strain)
# Out:
# Extracting subtree of 3526 samples.
# No input arguments passed; creating default tree.
# Completed in 547 msec
#
# Finished 'subtree' in 0.553 seconds

# %%
t
# Out:
# MATree object with 759 leaves.

# %%
node_ids = [n.id for n in t.depth_first_expansion() if not n.is_leaf()]
len(node_ids)
# Out:
# 757

# %%
def permute_ari():
    node_choices = np.random.choice(node_ids,size=df.lineage.nunique())
    fake_lineage_labels = []
    for strain in df.strain:
        tagged = False
        for anc in t.rsearch(strain):
            if anc.id in node_choices:
                fake_lineage_labels.append(anc.id)
                tagged = True
                break
        if not tagged:
            fake_lineage_labels.append('not assigned')
    return ari(df.SeabraLineage, fake_lineage_labels)
permute_ari()
# Out:
# 0.09880911120505816

# %%
perm_dist = [permute_ari() for i in range(10000)]

# %%
np.mean(perm_dist)
# Out:
# 0.08499804441540525

# %%
pos(perm_dist, ari(df.SeabraLineage, df['GRI Lineage Level 3']))
# Out:
# 100.0

# %% [markdown]
# We find that the ARI is much higher than expected at random.
